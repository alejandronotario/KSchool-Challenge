# %%
import pandas as pd
import numpy as np
import bz2

# %%
path_to_bookings = '/home/dsc/Data/challenge/bookings.csv.bz2'
path_to_searches = '/home/dsc/Data/challenge/bookings.csv.bz2'
# !bzcat {path_to_bookings} | head
# Out:
# act_date           ^source^pos_ctry^pos_iata^pos_oid  ^rloc          ^cre_date           ^duration^distance^dep_port^dep_city^dep_ctry^arr_port^arr_city^arr_ctry^lst_port^lst_city^lst_ctry^brd_port^brd_city^brd_ctry^off_port^off_city^off_ctry^mkt_port^mkt_city^mkt_ctry^intl^route          ^carrier^bkg_class^cab_class^brd_time           ^off_time           ^pax^year^month^oid
# 2013-03-05 00:00:00^1A    ^DE      ^a68dd7ae953c8acfb187a1af2dcbe123^1a11ae49fcbf545fd2afc1a24d88d2b7^ea65900e72d71f4626378e2ebd298267^2013-02-22 00:00:00^1708^0^ZRH     ^ZRH     ^CH      ^LHR     ^LON     ^GB      ^ZRH     ^ZRH     ^CH      ^LHR     ^LON     ^GB      ^ZRH     ^ZRH     ^CH      ^LHRZRH  ^LONZRH  ^CHGB    ^1^LHRZRH         ^VI^T        ^Y        ^2013-03-07 08:50:00^2013-03-07 11:33:37^-1^2013^3^NULL
# ...

# %%
bookings_csv = pd.read_csv (path_to_bookings, sep = '^', compression = 'bz2', usecols = ['arr_port', 'pax', 'year'], iterator = True )

bookings_csv.get_chunk (100)
# Out:
#     arr_port  pax  year
# 0   LHR        -1  2013
# 1   CLT         1  2013
# 2   CLT         1  2013
# 3   SVO         1  2013
# 4   SVO         1  2013
# 5   LGA         1  2013
# 6   LGA         1  2013
# 7   SIN         2  2013
# 8   SIN         2  2013
# 9   SIN         2  2013
# 10  SIN         2  2013
# 11  SIN        -2  2013
# 12  SIN        -2  2013
# 13  SIN        -2  2013
# 14  SIN        -2  2013
# 15  SIN         1  2013
# 16  SIN         1  2013
# 17  SIN         1  2013
# 18  SIN         1  2013
# 19  TUS         1  2013
# 20  CTA        -2  2013
# 21  CTA         2  2013
# 22  YWG         2  2013
# 23  YWG         2  2013
# 24  YWG        -2  2013
# 25  YWG         2  2013
# 26  YWG         2  2013
# 27  YWG        -2  2013
# 28  YWG        -2  2013
# 29  YWG         2  2013
# ..       ...  ...   ...
# 70  ZRH        -1  2013
# 71  ZRH        -1  2013
# 72  ZRH        -1  2013
# 73  ZRH        -1  2013
# 74  ZRH         1  2013
# 75  ZRH         1  2013
# ...

# %%
bookings_csv = pd.read_csv (path_to_bookings, sep = '^', compression = 'bz2', iterator = True )

bookings_csv.get_chunk (5)
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port    ...      \
# ...

# %% [markdown]
# # ejercicio 3 con searches

# %%
searches_csv = pd.read_csv (path_to_searches, sep = '^', compression = 'bz2', iterator = True )

searches_csv.get_chunk (5)
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port    ...      \
# ...

# %%
# !bzcat {path_to_searches} | head
# Out:
# act_date           ^source^pos_ctry^pos_iata^pos_oid  ^rloc          ^cre_date           ^duration^distance^dep_port^dep_city^dep_ctry^arr_port^arr_city^arr_ctry^lst_port^lst_city^lst_ctry^brd_port^brd_city^brd_ctry^off_port^off_city^off_ctry^mkt_port^mkt_city^mkt_ctry^intl^route          ^carrier^bkg_class^cab_class^brd_time           ^off_time           ^pax^year^month^oid
# 2013-03-05 00:00:00^1A    ^DE      ^a68dd7ae953c8acfb187a1af2dcbe123^1a11ae49fcbf545fd2afc1a24d88d2b7^ea65900e72d71f4626378e2ebd298267^2013-02-22 00:00:00^1708^0^ZRH     ^ZRH     ^CH      ^LHR     ^LON     ^GB      ^ZRH     ^ZRH     ^CH      ^LHR     ^LON     ^GB      ^ZRH     ^ZRH     ^CH      ^LHRZRH  ^LONZRH  ^CHGB    ^1^LHRZRH         ^VI^T        ^Y        ^2013-03-07 08:50:00^2013-03-07 11:33:37^-1^2013^3^NULL
# ...

# %% [markdown]
# # importar geobases

# %%
from GeoBases import GeoBase
geo_o = GeoBase(data='ori_por', verbose=False)
geo_a = GeoBase(data='airports', verbose=False)
geo_t = GeoBase(data='stations', verbose=False)

# %% [markdown]
# # comando geo_a.fuzzyFind (Approximate name matching)
# para averiguar el código de los aeropuertos y usarlo

# %%
madrid_code = geo_a.fuzzyFind('Madrid','name')
print (madrid_code)
# Out:
# [(0.9, 'MAD'), (0.7692307692307693, 'IXM')]

# %%
geo_o.get ('MAD', 'name')
# Out:
# 'Madrid / Barajas'

# %%
malaga_code = geo_a.fuzzyFind('Malaga','name')
print (malaga_code)
# Out:
# [(0.9, 'AGP'), (0.7692307692307693, 'PLQ'), (0.7692307692307693, 'MAK')]

# %%
geo_o.get ('AGP', 'name')
# Out:
# 'M\xc3\xa1laga Airport'

# %%
barcelona_code = geo_a.fuzzyFind('Barcelona','name')
print (barcelona_code)
# Out:
# [(0.9, 'BCN'), (0.7777777777777778, 'QAK')]

# %%
geo_o.get ('BCN', 'name')
# Out:
# 'Barcelona\xe2\x80\x93El Prat Airport'

# %%
import matplotlib.pyplot as plt

# %%
searches_csv = pd.read_csv (path_to_searches, sep = '^', compression = 'bz2', usecols = ['arr_port', 'pos_iata'], iterator = True )

searches_csv.get_chunk (20)
# Out:
#                             pos_iata  arr_port
# 0   a68dd7ae953c8acfb187a1af2dcbe123  LHR
# 1   e612b9eeeee6f17f42d9b0d3b79e75ca  CLT
# 2   e612b9eeeee6f17f42d9b0d3b79e75ca  CLT
# 3   0f984b3bb6bd06661c95529bbd6193bc  SVO
# 4   0f984b3bb6bd06661c95529bbd6193bc  SVO
# 5   0283592e45e392871f7e14b1e22a9aaf  LGA
# 6   0283592e45e392871f7e14b1e22a9aaf  LGA
# 7   5af045902bd23cab579915611d99e1e0  SIN
# 8   5af045902bd23cab579915611d99e1e0  SIN
# 9   5af045902bd23cab579915611d99e1e0  SIN
# 10  5af045902bd23cab579915611d99e1e0  SIN
# 11  5af045902bd23cab579915611d99e1e0  SIN
# 12  5af045902bd23cab579915611d99e1e0  SIN
# 13  5af045902bd23cab579915611d99e1e0  SIN
# 14  5af045902bd23cab579915611d99e1e0  SIN
# 15  5af045902bd23cab579915611d99e1e0  SIN
# 16  5af045902bd23cab579915611d99e1e0  SIN
# 17  5af045902bd23cab579915611d99e1e0  SIN
# 18  5af045902bd23cab579915611d99e1e0  SIN
# 19  f8d15f8b5e04f0cfcb62f299d059beb3  TUS
