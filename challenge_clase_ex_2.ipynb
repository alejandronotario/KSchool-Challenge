# %% [markdown]
# # ejercicio 2
# cosas a tener en cuenta:
#
# 1. familiarizarnos con los datos a trabajar
# 2. seleccionar las columnas de interés
# 3. tener claro qué hacer con las NaN
# 4. hacer plan de acción
# 5. desarrollar el código para que funcione con una muestra
# 6. ajustar el código para que trabaje con Big Data
# 7. Testear la aproximación de Big Data con una muestra
# 8. hacer trabajar el programa con big data

# %%
cd ~/Data/challenge/
# Out:
# /home/dsc/Data/challenge

# %%
# !ls
# Out:
# bookings.csv.bz2	 bookings.sample.csv.csv  searches.sample.csv.csv
# bookings.sample.csv	 searches.csv.bz2
# bookings.sample.csv.bz2  searches.sample.csv

# %% [markdown]
# ## familiarizarnos con los datos
# opciones:
# 1. prepar una muestra
# 2. leer csv con la opción nrows

# %%
import pandas as pd

# %%
b = pd.read_csv ('bookings.sample.csv.bz2', sep = '^', nrows = 1000)

# %% [markdown]
# ### el sample puede coger un header...

# %%
b.shape
# Out:
# (999, 38)

# %% [markdown]
# ### con este comand se ven en columna para evitar erro

# %%
b.columns.tolist()
# Out:
# ['act_date           ',
#  'source',
#  'pos_ctry',
#  'pos_iata',
#  'pos_oid  ',
#  'rloc          ',
#  'cre_date           ',
#  'duration',
#  'distance',
#  'dep_port',
#  'dep_city',
#  'dep_ctry',
#  'arr_port',
#  'arr_city',
#  'arr_ctry',
#  'lst_port',
#  'lst_city',
#  'lst_ctry',
#  'brd_port',
#  'brd_city',
#  'brd_ctry',
#  'off_port',
#  'off_city',
#  'off_ctry',
#  'mkt_port',
#  'mkt_city',
#  'mkt_ctry',
#  'intl',
#  'route          ',
#  'carrier',
#  'bkg_class',
#  'cab_class',
#  'brd_time           ',
#  'off_time           ',
#  'pax',
#  'year',
#  'month',
#  'oid      ']

# %%
b.head()
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port    ...      \
# ...

# %% [markdown]
# ### esta es la manera de obtener el head () con todas las columnas/opción alternativa a línea de comandos

# %%
pd.set_option ('display.max_columns', 100)

# %%
b.head()
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port  dep_city  dep_ctry  \
# ...

# %%
b.dtypes
# Out:
# act_date               object
# source                 object
# pos_ctry               object
# pos_iata               object
# pos_oid                object
# rloc                   object
# cre_date               object
# duration                int64
# distance                int64
# dep_port               object
# dep_city               object
# dep_ctry               object
# arr_port               object
# arr_city               object
# arr_ctry               object
# lst_port               object
# lst_city               object
# lst_ctry               object
# brd_port               object
# brd_city               object
# brd_ctry               object
# off_port               object
# off_city               object
# off_ctry               object
# mkt_port               object
# mkt_city               object
# mkt_ctry               object
# intl                    int64
# route                  object
# carrier                object
# bkg_class              object
# ...

# %%
b.isnull()
# Out:
#     act_date            source pos_ctry pos_iata pos_oid   rloc            \
# 0                 False  False    False    False     False          False
# 1                 False  False    False    False     False          False
# 2                 False  False    False    False     False          False
# 3                 False  False    False    False     False          False
# 4                 False  False    False    False     False          False
# 5                 False  False    False    False     False          False
# 6                 False  False    False    False     False          False
# 7                 False  False    False    False     False          False
# 8                 False  False    False    False     False          False
# 9                 False  False    False    False     False          False
# 10                False  False    False    False     False          False
# 11                False  False    False    False     False          False
# ...

# %%
b.isnull().sum()
# Out:
# act_date               0
# source                 0
# pos_ctry               0
# pos_iata               0
# pos_oid                0
# rloc                   0
# cre_date               0
# duration               0
# distance               0
# dep_port               0
# dep_city               0
# dep_ctry               0
# arr_port               0
# arr_city               0
# arr_ctry               0
# lst_port               0
# lst_city               0
# lst_ctry               0
# brd_port               0
# brd_city               0
# brd_ctry               0
# off_port               0
# off_city               0
# off_ctry               0
# mkt_port               0
# mkt_city               0
# mkt_ctry               0
# intl                   0
# route                  0
# carrier                0
# bkg_class              0
# cab_class              0
# brd_time               0
# off_time               0
# pax                    0
# year                   0
# month                  0
# ...

# %%
b.describe()
# Out:
#             duration      distance        intl         pax    year  month
# count     999.000000    999.000000  999.000000  999.000000   999.0  999.0
# mean    23959.061061    405.376376    0.643644    0.533534  2013.0    3.0
# std     54481.250534   1489.219442    0.479162    1.976471     0.0    0.0
# min        61.000000      0.000000    0.000000   -8.000000  2013.0    3.0
# 25%      3493.000000      0.000000    0.000000   -1.000000  2013.0    3.0
# 50%      6936.000000      0.000000    1.000000    1.000000  2013.0    3.0
# 75%     17940.000000      0.000000    1.000000    1.000000  2013.0    3.0
# max    482174.000000  10995.000000    1.000000   21.000000  2013.0    3.0

# %% [markdown]
# ## columnas de interés

# %%
b = pd.read_csv ('bookings.sample.csv.bz2', sep = '^', usecols = ['arr_port', 'pax', 'year'], nrows = 1000)

# %%
b.head()
# Out:
#    arr_port  pax  year
# 0  LHR        -1  2013
# 1  CLT         1  2013
# 2  CLT         1  2013
# 3  SVO         1  2013
# 4  SVO         1  2013

# %% [markdown]
# ##  "rloc= record locator" -> cuando haces reserva registro único | "cre_date"= fecha de reserva, primara vez que la haces" | "act_date = última actualización de la reserva, con cancelaciones incluidas" | "source = fuente de venta" | "arr_port = aeropuerto llegada" | "brd_port" = board port

# %% [markdown]
# ### es bueno ir situando el código que funciona en sun nuevo shell para seguir adelante

# %%
b = pd.read_csv ('bookings.sample.csv.bz2', sep = '^', usecols = ['arr_port', 'pax', 'year'], nrows = 1000)
b = b.dropna()

# %% [markdown]
# ## hace plan de acción
#
# 1. filtrar por año 2013
# 2. groupby arr_port
# 3. sum pax
# 4. sort
# 5. obtener los 10 primeros

# %% [markdown]
# ### filtrar por año 2013

# %%
b = b[b['year'] == 2013]
b.drop ('year', axis =1, inplace=True)

# %%
b.head()
# Out:
#    arr_port  pax
# 0  LHR        -1
# 1  CLT         1
# 2  CLT         1
# 3  SVO         1
# 4  SVO         1

# %%
arr_ports = b.groupby ('arr_port')

# %% [markdown]
# ### obtener los nombres de grupo y posiciones donde están en el data frame

# %%
arr_ports.groups
# Out:
# {'ACC     ': Int64Index([118, 119], dtype='int64'),
#  'ADD     ': Int64Index([207, 208, 301, 302], dtype='int64'),
#  'AGP     ': Int64Index([397, 398], dtype='int64'),
#  'ALA     ': Int64Index([76, 77], dtype='int64'),
#  'ALC     ': Int64Index([909, 910], dtype='int64'),
#  'ALG     ': Int64Index([34, 35, 36, 37, 558, 559], dtype='int64'),
#  'AMD     ': Int64Index([732], dtype='int64'),
#  'AMS     ': Int64Index([494, 888, 889, 890, 891], dtype='int64'),
#  'ANC     ': Int64Index([432, 433], dtype='int64'),
#  'ASU     ': Int64Index([548, 549, 550, 551, 724, 725], dtype='int64'),
#  'ATH     ': Int64Index([313, 314, 739, 748], dtype='int64'),
#  'ATL     ': Int64Index([147, 404, 908], dtype='int64'),
#  'ATQ     ': Int64Index([801, 802, 803], dtype='int64'),
#  'AUH     ': Int64Index([733, 734], dtype='int64'),
#  'AUS     ': Int64Index([380, 381], dtype='int64'),
#  'AYT     ': Int64Index([81, 82, 83, 500], dtype='int64'),
#  'BBI     ': Int64Index([151, 152], dtype='int64'),
# ...

# %% [markdown]
# ### ojo con los espacios 'ACC       '

# %%
arr_ports.get_group('ACC     ')
# Out:
#      arr_port  pax
# 118  ACC         3
# 119  ACC         3

# %%
type (arr_ports)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %% [markdown]
# ### diferencia entre loop para iterar o bien obtención de dataframe

# %%
for airport , val in arr_ports:
    print "%s" %(airport)
    print val['pax'].sum()
# Out:
# ACC
# 6
# ADD
# 2
# AGP
# 6
# ALA
# 2
# ALC
# 4
# ALG
# 0
# AMD
# 1
# AMS
# 1
# ANC
# 0
# ASU
# -10
# ATH
# 4
# ATL
# 3
# ATQ
# 1
# AUH
# 0
# AUS
# 2
# AYT
# 0
# BBI
# 0
# BCN
# 5
# BEY
# 4
# BHM
# -1
# BJV
# 8
# BJX
# 2
# BKK
# 2
# BLQ
# 2
# BLR
# 0
# BNA
# 4
# BNE
# 6
# BOG
# 0
# BOI
# 3
# BOM
# 5
# BOS
# 11
# BRD
# 2
# BRU
# 2
# BUD
# 0
# BUF
# 2
# BWI
# 10
# CAG
# 0
# CAI
# 2
# CAN
# 0
# CBR
# 0
# CCJ
# -3
# CCS
# 0
# CDG
# 4
# CGK
# 12
# CHQ
# 0
# CLT
# 5
# CMB
# 0
# COK
# 7
# COS
# 6
# CTA
# 0
# CUN
# 4
# CUR
# 0
# CUZ
# 0
# CVG
# 2
# CZM
# 4
# DAB
# 2
# DAC
# 4
# DAY
# 2
# DCA
# 50
# DEL
# 7
# DEN
# 6
# DFW
# -2
# DMM
# 2
# DOH
# 3
# DTW
# 3
# DXB
# 0
# ELP
# 0
# EWR
# 8
# EZE
# 2
# FAI
# 4
# FAO
# 2
# FCO
# 3
# FLL
# 13
# FRA
# 4
# FUE
# 0
# GAU
# -3
# GIZ
# 0
# GRU
# 0
# GUM
# 2
# HAV
# 0
# HER
# 4
# HKG
# 2
# HMO
# 1
# HNL
# 0
# ICN
# 0
# IND
# 3
# ISB
# 0
# IST
# 7
# ISU
# 0
# IXE
# 0
# JAC
# 0
# JAX
# 0
# JED
# -1
# JFK
# 14
# JNB
# 2
# KHI
# 2
# KIV
# 0
# KUL
# 2
# LAO
# ...

# %%
arr_ports.sum()
# Out:
#           pax
# arr_port
# ACC         6
# ADD         2
# AGP         6
# ALA         2
# ALC         4
# ALG         0
# AMD         1
# AMS         1
# ANC         0
# ASU       -10
# ATH         4
# ATL         3
# ATQ         1
# AUH         0
# AUS         2
# AYT         0
# BBI         0
# BCN         5
# BEY         4
# BHM        -1
# BJV         8
# BJX         2
# BKK         2
# BLQ         2
# BLR         0
# BNA         4
# BNE         6
# BOG         0
# BOI         3
# BOM         5
# ...       ...
# SOF         1
# SSA         2
# STL         2
# SVO        12
# SVQ         1
# SXM         0
# SYD        -1
# TIA         2
# TLS         0
# TLV         1
# TPA         2
# TUS         2
# TXL         0
# TYR         2
# ULN         2
# UVF         0
# VPS         2
# VVI         0
# WAW         0
# WDH         2
# WRO         1
# YHZ         2
# YNB         0
# YUL         0
# YVR         5
# YWG         4
# YXE         1
# YYC         0
# YYZ         2
# ...

# %%
arr_ports.sum().sort_values ('pax', ascending = False).head (10)
# Out:
#           pax
# arr_port
# DCA        50
# JFK        14
# FLL        13
# PVG        13
# CGK        12
# LGA        12
# SVO        12
# LAS        11
# BOS        11
# MIA        11

# %% [markdown]
# ### ahora toca implementar la solución obtenida para la muestra al big data. Para ello vamos a meter todo lo que funciona en un shell

# %%
b = pd.read_csv ('bookings.sample.csv.bz2', sep = '^', usecols = ['arr_port', 'pax', 'year'], nrows = 1000)
b = b.dropna()
b = b[b['year'] == 2013]
b.drop ('year', axis =1, inplace=True)
arr_ports = b.groupby ('arr_port')
arr_ports.sum().sort_values ('pax', ascending = False).head (10)

# %% [markdown]
# ### chunks...ver distintos tipos de fichero

# %%
b = pd.read_csv ('bookings.sample.csv.bz2', sep = '^', usecols = ['arr_port', 'pax', 'year']\
                 ,iterator = True)

# %%
type(b)
# Out:
# pandas.io.parsers.TextFileReader

# %%
b2 = pd.read_csv ('bookings.sample.csv.bz2', sep = '^', usecols = ['arr_port', 'pax', 'year'], nrows = 1000)
type (b2)
# Out:
# pandas.core.frame.DataFrame

# %%
b0=b.get_chunk (300)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-81-ccdb18a086f8> in <module>()
# ----> 1 b0=b.get_chunk (300)
#
# /home/dsc/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in get_chunk(self, size)
#     970         if size is None:
#     971             size = self.chunksize
# --> 972         return self.read(nrows=size)
#     973
#     974
#
# /home/dsc/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#     937                 raise ValueError('skipfooter not supported for iteration')
#     938
# --> 939         ret = self._engine.read(nrows)
#     940
#     941         if self.options.get('as_recarray'):
#
# /home/dsc/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1506     def read(self, nrows=None):
#    1507         try:
# -> 1508             data = self._reader.read(nrows)
# ...

# %%
type (b0)
# Out:
# pandas.core.frame.DataFrame

# %%
b = pd.read_csv ('bookings.sample.csv.bz2', sep = '^', usecols = ['arr_port', 'pax', 'year']\
                 ,chunksize=400)

# %%
type (b)
# Out:
# pandas.io.parsers.TextFileReader

# %%
b0=b.next()

# %%
b1 = b.next()

# %%
b2 = b.get_chunk(400)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-79-af8a603f80f0> in <module>()
# ----> 1 b2 = b.get_chunk(400)
#
# /home/dsc/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in get_chunk(self, size)
#     970         if size is None:
#     971             size = self.chunksize
# --> 972         return self.read(nrows=size)
#     973
#     974
#
# /home/dsc/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#     937                 raise ValueError('skipfooter not supported for iteration')
#     938
# --> 939         ret = self._engine.read(nrows)
#     940
#     941         if self.options.get('as_recarray'):
#
# /home/dsc/anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1506     def read(self, nrows=None):
#    1507         try:
# -> 1508             data = self._reader.read(nrows)
# ...

# %%
b = pd.read_csv ('bookings.sample.csv.bz2', sep = '^', usecols = ['arr_port', 'pax', 'year']\
                 ,chunksize = 400)
for i, chunk in enumerate (b):
    print chunk.head()
    if i == 3:
        break
# Out:
#    arr_port  pax  year
# 0  LHR        -1  2013
# 1  CLT         1  2013
# 2  CLT         1  2013
# 3  SVO         1  2013
# 4  SVO         1  2013
#      arr_port  pax  year
# 400  DCA        21  2013
# 401  ORD         1  2013
# 402  ORD         1  2013
# 403  ORD        -1  2013
# 404  ATL         1  2013
#      arr_port  pax  year
# 800  ORD         1  2013
# 801  ATQ         1  2013
# 802  ATQ         1  2013
# 803  ATQ        -1  2013
# 804  YVR         1  2013

# %%
bc = pd.read_csv ('bookings.sample.csv.bz2', sep = '^', usecols = ['arr_port', 'pax', 'year']\
                 ,chunksize = 400)

sum_chunks = pd.DataFrame()

for i, b in enumerate (bc):
    print "Chunk: %d, size of chunk %d"%(i+1, len(b))
    b = b[b['year'] == 2013]
    b.drop ('year', axis =1, inplace=True)
    arr_ports = b.groupby ('arr_port')
    chunk_result = arr_ports.sum()
    sum_chunks = sum_chunks.append (chunk_result)
sum_chunks.head()
# Out:
# Chunk: 1, size of chunk 400
# Chunk: 2, size of chunk 400
# Chunk: 3, size of chunk 199
#           pax
# arr_port
# ACC         6
# ADD         2
# AGP         6
# ALA         2
# ALG         0

# %%
sum_chunks.head()
# Out:
#           pax
# arr_port
# ACC         6
# ADD         2
# AGP         6
# ALA         2
# ALG         0

# %%
sum_chunks.groupby(sum_chunks.index).pax.sum().sort_values(ascending = False).head(10)
# Out:
# arr_port
# DCA         50
# JFK         14
# FLL         13
# PVG         13
# SVO         12
# LGA         12
# CGK         12
# MIA         11
# LAS         11
# BOS         11
# Name: pax, dtype: int64

# %% [markdown]
# ###  lo guardamos en un fichero

# %%
top_10_airports = sum_chunks.groupby(sum_chunks.index)\
    .pax.sum().sort_values(ascending = False).reset_index()

# %%
top_10_airports.head()
# Out:
#    arr_port  pax
# 0  DCA        50
# 1  JFK        14
# 2  FLL        13
# 3  PVG        13
# 4  SVO        12

# %% [markdown]
# ### ahora comprbamos abriendo la muestra sin chunks para ver si da lo mismo y lo hemos hecho correctamente

# %%
b = pd.read_csv ('bookings.sample.csv.bz2', sep = '^', usecols = ['arr_port', 'pax', 'year'])
b = b.dropna()
b = b[b['year'] == 2013]
b.drop ('year', axis =1, inplace=True)
arr_ports = b.groupby ('arr_port')
arr_ports.sum().sort_values ('pax', ascending = False).head ()
# Out:
#           pax
# arr_port
# DCA        50
# JFK        14
# FLL        13
# PVG        13
# CGK        12

# %%
bc = pd.read_csv ('bookings.csv.bz2', sep = '^', usecols = ['arr_port', 'pax', 'year']\
                 ,chunksize = 1000000)

sum_chunks = pd.DataFrame()

for i, b in enumerate (bc):
    print "Chunk: %d, size of chunk %d"%(i+1, len(b))
    b = b[b['year'] == 2013]
    b.drop ('year', axis =1, inplace=True)
    arr_ports = b.groupby ('arr_port')
    chunk_result = arr_ports.sum()
    sum_chunks = sum_chunks.append (chunk_result)
top_10_airports = sum_chunks.groupby(sum_chunks.index)\
    .pax.sum().sort_values(ascending = False).reset_index()
# Out:
# Chunk: 1, size of chunk 1000000
# Chunk: 2, size of chunk 1000000
# Chunk: 3, size of chunk 1000000
# Chunk: 4, size of chunk 1000000
# Chunk: 5, size of chunk 1000000
# Chunk: 6, size of chunk 1000000
# /home/dsc/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Chunk: 7, size of chunk 1000000
# Chunk: 8, size of chunk 1000000
# Chunk: 9, size of chunk 1000000
# Chunk: 10, size of chunk 1000000
# Chunk: 11, size of chunk 10

# %%
top_10_airports.head(10)
# Out:
#    arr_port      pax
# 0  LHR       88809.0
# 1  MCO       70930.0
# 2  LAX       70530.0
# 3  LAS       69630.0
# 4  JFK       66270.0
# 5  CDG       64490.0
# 6  BKK       59460.0
# 7  MIA       58150.0
# 8  SFO       58000.0
# 9  DXB       55590.0

# %%
len (top_10_airports)
# Out:
# 2274

# %%
from GeoBases import GeoBase

# %%
geoDict = GeoBase(data = 'ori_por', verbose = False)

# %%
geoDict.fields
# Out:
# ['__key__',
#  '__dup__',
#  '__par__',
#  '__lno__',
#  'iata_code',
#  'icao_code',
#  'faa_code',
#  'is_geonames',
#  'geoname_id',
#  'valid_id',
#  'name',
#  'asciiname',
#  'lat',
#  'lng',
#  'fclass',
#  'fcode',
#  'page_rank',
#  'date_from',
#  'date_until',
#  'comment',
#  'country_code',
#  'cc2',
#  'country_name',
#  'continent_name',
#  'adm1_code',
#  'adm1_name_utf',
#  'adm1_name_ascii',
#  'adm2_code',
#  'adm2_name_utf',
#  'adm2_name_ascii',
#  'adm3_code',
#  'adm4_code',
#  'population',
#  'elevation',
#  'gtopo30',
#  'timezone',
#  'gmt_offset',
#  'dst_offset',
#  'raw_offset',
#  'moddate',
#  'city_code',
#  'city_name_utf',
#  'city_name_ascii',
#  'tvl_por_list@raw',
#  'tvl_por_list',
#  'state_code',
#  'location_type@raw',
#  'location_type',
#  'wiki_link',
#  'alt_name_section@raw',
#  'alt_name_section',
#  '__gar__']

# %%
geoDict.get? ## help

# %%
geoDict.get ('LHR', 'city_name_utf')
# Out:
# 'London'

# %%
geoDict.get ('LHR', 'name')
# Out:
# 'London Heathrow Airport'

# %%
geoDict.get ('LHR') ['name']
# Out:
# 'London Heathrow Airport'

# %%
geoDict.get (top_10_airports['arr_port'][0].strip())['name']
# Out:
# 'London Heathrow Airport'

# %%
top_10_airports['Airport_name'] = top_10_airports['arr_port']\
.map(lambda x: geoDict.get (x.strip())['name'])

# %% [markdown]
# ### en map functions hemos utlizado.map porque aplica a los elementos de una columna o fila

# %%
top_10_airports
# Out:
#       arr_port      pax                                       Airport_name
# 0     LHR       88809.0                            London Heathrow Airport
# 1     MCO       70930.0                      Orlando International Airport
# 2     LAX       70530.0                  Los Angeles International Airport
# 3     LAS       69630.0                    Mc Carran International Airport
# 4     JFK       66270.0               John F Kennedy International Airport
# 5     CDG       64490.0                          Paris - Charles-de-Gaulle
# 6     BKK       59460.0                                       Suvarnabhumi
# 7     MIA       58150.0                        Miami International Airport
# 8     SFO       58000.0                San Francisco International Airport
# 9     DXB       55590.0                        Dubai International Airport
# 10    ORD       53200.0               Chicago O'Hare International Airport
# ...

# %%
top_10_airports.to_csv ('top_10_airports.csv', sep = '^', index = False)

# %%
# !ls -l
# Out:
# total 1015172
# -rw-rw-r-- 1 dsc dsc 554970628 Jan  4  2016 bookings.csv.bz2
# -rw-rw-r-- 1 dsc dsc    425006 May 19 17:40 bookings.sample.csv
# -rw-rw-r-- 1 dsc dsc     54834 May 19 17:16 bookings.sample.csv.bz2
# -rw-rw-r-- 1 dsc dsc    425006 May 19 17:45 bookings.sample.csv.csv
# -rw-rw-r-- 1 dsc dsc 483188920 Jan  4  2016 searches.csv.bz2
# -rw-rw-r-- 1 dsc dsc    181739 May 19 17:40 searches.sample.csv
# -rw-rw-r-- 1 dsc dsc    181739 May 19 17:45 searches.sample.csv.csv
# -rw-rw-r-- 1 dsc dsc     84696 May 19 20:56 top_10_airports.csv
